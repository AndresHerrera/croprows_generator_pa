# %%
import numpy as np
import sys
#Move to parent folder
sys.path.insert(0, '../croprows-cli/src/')

import croprows_globals as crglobals

import croprows_utils as crutils


import imp 
imp.reload(crglobals)
imp.reload(crutils)
# Out:
# croprows_globals [ module loaded ]
# croprows_utils [ module loaded ]
# croprows_globals [ module loaded ]
# croprows_utils [ module loaded ]
# <module 'croprows_utils' from '../croprows-core/src/croprows_utils.py'>

# %%
a=[12,12.3,12.32, 18, 22, 40 , 50 ,50.34,32,12.24,12.24,18.1 , 18.23, 32, 40.1,40.12,40.22,40.23,40.25,40.30,56,57]
a2= np.argsort(a)
a3= np.sort(a)

# %%
a
# Out:
# [12,
#  12.3,
#  12.32,
#  18,
#  22,
#  40,
#  50,
#  50.34,
#  32,
#  12.24,
#  12.24,
#  18.1,
#  18.23,
#  32,
#  40.1,
#  40.12,
#  40.22,
#  40.23,
#  40.25,
#  40.3,
#  56,
#  57]

# %%
a2
# Out:
# array([ 0,  9, 10,  1,  2,  3, 11, 12,  4,  8, 13,  5, 14, 15, 16, 17, 18,
#        19,  6,  7, 20, 21])

# %%
a3
# Out:
# array([ 12.  ,  12.24,  12.24,  12.3 ,  12.32,  18.  ,  18.1 ,  18.23,
#         22.  ,  32.  ,  32.  ,  40.  ,  40.1 ,  40.12,  40.22,  40.23,
#         40.25,  40.3 ,  50.  ,  50.34,  56.  ,  57.  ])

# %%
c = crutils.removeAdjacentsInArray(a3)

# %%
c
# Out:
# [12.0,
#  12.24,
#  12.300000000000001,
#  12.32,
#  18.0,
#  18.100000000000001,
#  18.23,
#  22.0,
#  32.0,
#  40.0,
#  40.100000000000001,
#  40.119999999999997,
#  40.219999999999999,
#  40.229999999999997,
#  40.25,
#  40.299999999999997,
#  50.0,
#  50.340000000000003,
#  56.0,
#  57.0]

# %%
x_pairs = zip([0]+c, c)
new_x = [pair[1] for pair in x_pairs if abs(pair[0]-pair[1]) > 0.2]
new_x
# Out:
# [12.0, 12.24, 18.0, 22.0, 32.0, 40.0, 50.0, 50.340000000000003, 56.0, 57.0]

# %%
#TEST WITH REAL DATA

# %%
kkk = [19.819724522470388, 19.96672545343523, 21.98867349470859, 19.904328302309818, 19.890638313353172, 19.956748842485858, 19.975453483487943, 19.989293208023035, 15.681190122693456, 15.744692097092864, 13.097813574948319, 13.113307605396129, 13.127049461289422, 12.113628512419165, 12.15587389201943, 12.232560897637853, 12.201540743666103, 8.623162695573303, 10.577659542320035, 8.822733355082159, 11.378710855896319, 10.601194191200367, 8.771036299703635, 10.59514592830271, 8.596052382142286, 10.626413233650185, 8.794694288716641]

# %%
kkk
# Out:
# [19.819724522470388,
#  19.96672545343523,
#  21.98867349470859,
#  19.904328302309818,
#  19.890638313353172,
#  19.956748842485858,
#  19.975453483487943,
#  19.989293208023035,
#  15.681190122693456,
#  15.744692097092864,
#  13.097813574948319,
#  13.113307605396129,
#  13.127049461289422,
#  12.113628512419165,
#  12.15587389201943,
#  12.232560897637853,
#  12.201540743666103,
#  8.623162695573303,
#  10.577659542320035,
#  8.822733355082159,
#  11.378710855896319,
#  10.601194191200367,
#  8.771036299703635,
#  10.59514592830271,
#  8.596052382142286,
#  10.626413233650185,
#  8.794694288716641]

# %%
len(kkk)
# Out:
# 27

# %%
kk= np.sort(kkk)
kk = crutils.removeAdjacentsInArray(kk)

# %%
kk
# Out:
# [8.5960523821422861,
#  8.6231626955733027,
#  8.7710362997036349,
#  8.7946942887166415,
#  8.8227333550821587,
#  10.577659542320035,
#  10.59514592830271,
#  10.601194191200367,
#  10.626413233650185,
#  11.378710855896319,
#  12.113628512419165,
#  12.15587389201943,
#  12.201540743666103,
#  12.232560897637853,
#  13.097813574948319,
#  13.113307605396129,
#  13.127049461289422,
#  15.681190122693456,
#  15.744692097092864,
#  19.819724522470388,
#  19.890638313353172,
#  19.904328302309818,
#  19.956748842485858,
#  19.966725453435231,
#  19.975453483487943,
#  19.989293208023035,
#  21.988673494708589]

# %%
x_pairs = zip([0]+kk, kk)
new_x = [pair[1] for pair in x_pairs if abs(pair[0]-pair[1]) > 0.2]

# %%
new_x
# Out:
# [8.5960523821422861,
#  10.577659542320035,
#  11.378710855896319,
#  12.113628512419165,
#  13.097813574948319,
#  15.681190122693456,
#  19.819724522470388,
#  21.988673494708589]

# %%
len(new_x)
# Out:
# 8

# %%
#### FINN #####

# %%
np.argwhere(new_x)
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6],
#        [7]])

# %%
a = kk
b = new_x

# %%
a
# Out:
# [8.5960523821422861,
#  8.6231626955733027,
#  8.7710362997036349,
#  8.7946942887166415,
#  8.8227333550821587,
#  10.577659542320035,
#  10.59514592830271,
#  10.601194191200367,
#  10.626413233650185,
#  11.378710855896319,
#  12.113628512419165,
#  12.15587389201943,
#  12.201540743666103,
#  12.232560897637853,
#  13.097813574948319,
#  13.113307605396129,
#  13.127049461289422,
#  15.681190122693456,
#  15.744692097092864,
#  19.819724522470388,
#  19.890638313353172,
#  19.904328302309818,
#  19.956748842485858,
#  19.966725453435231,
#  19.975453483487943,
#  19.989293208023035,
#  21.988673494708589]

# %%
b
# Out:
# [8.5960523821422861,
#  10.577659542320035,
#  11.378710855896319,
#  12.113628512419165,
#  13.097813574948319,
#  15.681190122693456,
#  19.819724522470388,
#  21.988673494708589]

# %%
c = np.setdiff1d(a,b)

# %%
get_indexes = lambda x, xs: [i for (y, i) in zip(xs, range(len(xs))) if x == y]

k=[]
i=0
for x in b:
    print(b[i])
    print(get_indexes(b[i],a))
    k.append(get_indexes(b[i],a)[0])
    i=i+1
    #print(get_indexes(b[i],a))
# Out:
# 8.59605238214
# [0]
# 10.5776595423
# [5]
# 11.3787108559
# [9]
# 12.1136285124
# [10]
# 13.0978135749
# [14]
# 15.6811901227
# [17]
# 19.8197245225
# [19]
# 21.9886734947
# [26]

# %%
k
# Out:
# [0, 5, 9, 10, 14, 17, 19, 26]

# %%
m=[]
i=0
for x in k:
    m.append(a[k[i]])
    i=i+1

# %%
m
# Out:
# [8.5960523821422861,
#  10.577659542320035,
#  11.378710855896319,
#  12.113628512419165,
#  13.097813574948319,
#  15.681190122693456,
#  19.819724522470388,
#  21.988673494708589]

# %% [markdown]
# <h1>test 1 </h1>

# %%
###another example
# A more compact example given a list of numbers.
C = [1.1, 1.2, 1.3, 1.5, 1.6, 1.4]
# In-place sort.
C.sort()

# %%
C
# Out:
# [1.1, 1.2, 1.3, 1.4, 1.5, 1.6]

# %%
import itertools
from statistics import mean

# %%
def grouper(iterable, criteria=None):
    if criteria is None:
        criteria = make_keyfcn()
    result = []
    for k, g in itertools.groupby(iterable, criteria):
        result.append(list(g))
    return result

def make_keyfcn(width=0.5):
    "Grouping critera."
    key = None
    def keyfcn(x):
        """As long as x is < key, keep returning key.

        Update when x >= key.
        """
        nonlocal key
        if key is None:  # When called the first time.
            key = x + width
        elif x >= key:
            key = x + width
        return key
    return keyfcn

# %%
lc = list(round(mean(g), 2) for g in grouper(C))
print("Average C", lc)
# Out:
# Average C [1.3, 1.6]

# %%
lc = list(round(mean(g), 2) for g in grouper(kkk))
print("Average C", lc)
# Out:
# Average C [19.89, 13.54]

# %% [markdown]
# <h1> test2 </h1>

# %%
A = [1, 1.01, 1.1, 2, 3, 3.2, 4, 5,4.3,5.4,3.2,4.3]
groups, current_group, first = [], [], A[0]
for item in A:
    # Check if this element falls under the current group
    if item - first <= 0.5:
        current_group.append(item)
    else:
        # If it doesn't, create a new group and add old to the result
        groups.append(current_group[:])
        current_group, first = [item], item
# Add the last group which was being gathered to the result
groups.append(current_group[:])

# %%
zavg=[sum(item) / len(item) for item in groups]

# %%
print(zavg)
# Out:
# [1.0366666666666666, 2.0, 3.1, 4.0, 4.44]

# %%
zmax=[max(item) for item in groups]

# %%
print(zmax)
# Out:
# [1.1, 2, 3.2, 4, 5.4]

# %%
zmin=[min(item) for item in groups]
print(zmin)
# Out:
# [1, 2, 3, 4, 3.2]

# %%
zmavg=[np.average(item) for item in groups]
print(zmavg)
# Out:
# [1.0366666666666666, 2.0, 3.1000000000000001, 4.0, 4.4400000000000004]

# %%
zmedian=[np.median(item) for item in groups]
print(zmedian)
# Out:
# [1.01, 2.0, 3.1000000000000001, 4.0, 4.2999999999999998]

# %%
### test real aray 
testarr = [0.99999999998739764, 13.122633923486505, 13.737126214282819, 16.231660000999728, 20.441512193654418, 24.585797519192134, 35.615222078673774, 35.634299863112638, 35.651596833758369, 35.651948859381328, 35.656808247806815, 35.661283365781223, 35.664126769789092, 35.66513583592684, 35.749131910513228, 35.80708034640827, 35.814507676207334, 35.815760262544707, 35.821141212236654, 35.836945137235872, 35.837160669756344, 35.842810966207182, 35.975153357484693, 36.047492843967582, 36.049517535653813, 36.057704158558352, 36.068645181562523, 36.074343723051072, 36.081995445148465, 36.09608818011025, 36.353603383330537, 36.363717773046496, 36.379005649556589, 36.389590994067049, 36.415269996343554, 36.453431441854569, 36.470534890021256, 36.47957930188273, 36.699253772659681, 36.721612604353275, 36.792948184140826, 36.802437256237937, 36.859572335554326, 36.875771716618544, 37.123337156286695, 37.221986382301473, 37.22983652121831, 37.325799159366916, 37.344691154657603, 37.346492277367453, 37.596132067808121, 37.635056920940052, 37.671251352274929, 37.724577878428668, 37.778514180395611, 37.899978100847534, 37.907254921173234, 37.916768427586902, 37.981730100595804, 38.283013921584619, 38.434104294185808, 38.465741411079925, 38.483263854061427, 38.583379353796509, 38.611707813034521, 38.612944506122311, 38.613451953622807, 38.672557866148395, 39.175168160727566, 39.218645805875191, 39.220113327870273, 39.250773193048154, 39.255590176521245, 39.262420708935672, 39.325663567572164, 39.754873313631087, 39.920186517613836, 39.925008298310409, 39.948156122201802, 40.000177710344737, 40.016017558341808, 40.025746641669109, 40.078791873060894, 40.643223212411712, 40.75456405944584, 40.812214512026401, 40.82710751855096, 40.883921102430051, 40.910491675861614, 40.937731296580594, 40.946506949178776, 40.997841779587056, 41.56210493913963, 41.57928106525064, 41.617149586960217, 41.70933370301951, 41.71914330763024, 41.758520097748075, 41.820538322162996, 41.820750462598767, 41.882709125925679, 42.5301422509581, 42.54859992250681, 42.592690853759628, 42.593033801266905, 42.693378757942916, 42.72368429509114, 42.750153451573851, 42.810703404895982, 42.850175093958171, 42.876397188696444, 42.890446138414866, 43.488149047455536, 43.54532090078002, 43.56457297273387, 43.573395114501793, 43.64517366662416, 43.700523813785388, 43.724239464926754, 43.727432674038141, 43.811073522751997, 43.84210971201194, 44.085454989384388, 44.469661773055662, 44.581843407234025, 44.594118868170646, 44.612040194498675, 44.703515837304664, 44.776461749593437, 44.844699330609302, 45.227643543506353, 45.595164530604329, 45.62702182052211, 45.627794255750693, 45.628628277003997, 45.771516157160427, 45.800309764876033, 45.927295704085061, 45.938083160658458, 45.950840049548681, 46.678098058247755, 46.701743091022955, 46.806009960069318, 46.809575517531457, 46.836597443863155, 46.893532477599173, 46.895621470955909, 46.997550039286139, 47.010164010238135, 47.03617093420727, 47.113888658225299, 48.020238715689722, 48.022760580384443, 48.0452085235708, 48.05396423073428, 48.094376572166318, 48.144079806186745, 48.152959167636325, 48.236391270622036, 48.255892460007146, 48.265854408994613, 49.217767441834027, 49.219809303881839, 49.242348601568196, 49.294632410106921, 49.358897510739645, 49.36228536425309, 49.385539945717241, 49.401274313855588, 49.575922393953931, 50.151038825492016, 50.407162400162413, 50.437176894348809, 50.502754258809873, 50.534432207170774, 50.600533752590295, 50.623639942102713, 50.647887612024881, 50.659439615389573, 51.335419703693795, 51.592806694738485, 51.672985899403912, 51.718197161683356, 51.729689419907366, 51.792246315965421, 51.86160785624471, 52.554462112558902, 52.866520604374507, 52.927248871643201, 53.002762181980188, 53.031179253861474, 53.105322949523675, 53.212492179730546, 53.27327703389301, 53.80582998259348, 53.963178199296301, 54.207602890540073, 54.263368057764374, 54.293610684124459, 54.315207175834452, 54.34243668329664, 54.420208895904359, 54.647743639538056, 55.489135729220145, 55.49822014519939, 55.527064605233569, 55.709207490389879, 55.812322140230748, 55.878488073022616, 55.946498345748594, 56.295196648827449, 56.592158319025032, 56.83992075692916, 56.960683903543575, 56.982942762013884, 56.98415739471681, 57.118160262583444, 57.137757924124685, 58.254099147936238, 58.349088260094796, 58.431668090302907, 58.441769886601243, 58.443490295674223, 58.574591415266788, 58.608798221721422, 58.766163732203694, 59.030828484775149, 59.277189910549126, 59.613038667198055, 59.689036402155224, 59.782021014866665, 59.840567396394647, 59.847406056833329, 59.870240905734008, 60.040869277591071, 60.685702379971531, 61.049405762982204, 61.064443740772695, 61.070087073351189, 61.135845384587064, 61.166718249359256, 61.219247683932664, 61.225382762537976, 61.275033254731206, 61.327748931722169, 62.546448239142954, 62.634512797395722, 62.676445290758778, 62.729981558352335, 62.964869247657717, 63.024149899839642, 63.083800113973602, 63.196336781933191, 63.205076816695829, 63.212857090770775, 64.589142099588059, 64.67782610967302, 64.914981239590546, 64.940451050284366, 64.948483381399754, 65.932348466317194, 65.982402681354401, 66.440003358568902, 66.666263119804469, 66.717798260289868, 66.746377835442601, 66.845502184748227, 66.960080305009726, 67.75059808366494, 68.319588486349545, 68.398408014916512, 68.451378155497153, 68.482714506977985, 68.541755828320618, 68.554312143932634, 68.604401582433894, 68.749647117194627, 68.76981362832565, 70.037621602243348, 70.129648671878968, 70.142837517767376, 70.279773356201829, 70.380053743973903, 70.580862768234752, 70.584377401269336, 70.594182650091767, 71.647641813463579, 71.983217313868423, 72.189815294900868, 72.201683146525141, 72.209828975144049, 72.328955184233394, 72.463956147150043, 72.526854087120952, 72.666311443203867, 74.010862827451831, 74.065206747097932, 74.116206775302686, 74.162016481592062, 74.288276953316696, 74.341158153153231, 74.347151137739019, 74.367655002362724, 74.525754801311663, 75.435327059640386, 75.484762006500787, 75.622071716264557, 75.630905532980265, 75.639990961703731, 75.676733427508708, 75.790885024909997, 75.912058757746834, 76.088591109644554, 77.066116416145093, 77.096005850605025, 77.128020768021344, 77.17560209777109, 77.219838957059082, 77.221066958628001, 77.369259804342207, 77.370624243454358, 77.43633718859202, 77.536435506108916, 78.714250008427186, 78.714640874764001, 78.735610889553811, 78.773047794353445, 78.809341909585001, 78.914363481795391, 78.93523806491531, 78.985117302122134, 78.996677981340767, 79.21223042500452, 80.267130175270708, 80.30105151293688, 80.351783773005423, 80.429141045616362, 80.50569965279395, 80.571487994351912, 80.573483745668398, 80.76849309897969, 81.694743261416349, 81.747407446207532, 81.823646983470695, 81.851062630651455, 81.878823138600012, 81.988287070297446, 82.013396825391425, 82.019676359307141, 82.036644349863494, 82.0807657766197, 83.379678671059594, 83.403650752471393, 83.445031079098442, 83.458134424436651, 83.61033680501076, 83.674423475346302, 83.67478462831329, 83.711993811349217, 83.725920464267389, 83.792908471546326, 84.996227254635542, 85.026862759550681, 85.028656760472245, 85.106580252002573, 85.171148396794507, 85.175294315432623, 85.202871686403512, 85.236440091632844, 85.263070952476994, 86.515737528524767, 86.557493809211977, 86.561517337633404, 86.578358573592737, 86.64595557535371, 86.800080833022136, 86.844567076501022, 86.891305349835108, 87.044408229369481, 87.150175179952086, 88.137408698803739, 88.273766683576412, 88.284790725702436, 88.314183268998832, 88.326858759964253, 88.449414738223723, 88.490809134552592, 88.602975380429797, 89.36142684884075, 89.743414516552505, 89.845956972632848, 89.883334241163723, 89.899298753710525, 89.900357426366384, 89.96850234221111, 90.02638852069002, 90.062985541751047, 90.075597589900738, 91.27538552856393, 91.406256446271243, 91.448260184861141, 91.459817564038318, 91.480512889935326, 91.519978567098406, 91.616359634572277, 91.673831667573808, 91.784519318953556, 93.016633704064049, 93.073591804100928, 93.170294119245128, 93.203059009887767, 93.226614516602666, 93.289756614312623, 93.346964222176851, 93.423265189772792, 93.461396609320673, 93.695068130066517, 94.501031522363306, 94.502359925663541, 94.595108254183202, 94.645187257088395, 94.687572007298826, 94.707335752960759, 94.751305285088321, 94.950900144963171, 95.021242455847656, 95.174606588172935, 96.064324610305519, 96.105717711598942, 96.145524991607488, 96.161750081286385, 96.169318526288961, 96.311102401133283, 96.312932246132178, 96.398745927366505, 96.44211672899452, 96.572060510261707, 96.720855253630063, 97.668052345414068, 97.686676018948063, 97.720141930898933, 97.730692789364085, 97.73150670766708, 97.733061599727208, 97.903324461237645, 98.067220964455458, 98.069836245310327, 99.016240358649725, 99.187571632942607, 99.225563133348999, 99.244698492726684, 99.29277489149473, 99.307196048633742, 99.320776651456725, 99.398175137194201, 99.460238152858139, 99.569298775205411, 100.74427228691248, 100.75882524878594, 100.78954946521365, 100.81803671972534, 100.84363050336006, 100.89224489043872, 100.95372037803864, 100.96167046892738, 100.97565456588569, 100.98194900180718, 101.16994629722916, 102.26414791984146, 102.29386119073169, 102.33496686773179, 102.33710070596815, 102.36524360034764, 102.3805209410625, 102.47109826536746, 102.65791706650505, 102.67942101547158, 102.70216474080289, 103.69550394740158, 103.75751402136096, 103.83495299699469, 103.86426575307196, 103.94595958569293, 103.94888929386718, 104.00973757469069, 104.23152674262074, 104.32779257209495, 105.28078304494483, 105.29382384659188, 105.35948322523741, 105.36117537007625, 105.36904943013992, 105.47202924639973, 105.56534148068312, 105.67601751073151, 105.82663454405704, 106.95429014096558, 106.95584969254533, 107.00359854559444, 107.03170663644485, 107.0649742255566, 107.13745822088406, 107.23739733169322, 107.26944340886124, 107.31301136326891, 108.4346518321957, 108.5150317658497, 108.51974506819084, 108.54500669151855, 108.55072010641597, 108.56132356384391, 108.66901316154753, 108.68999643179511, 108.86192067168204, 108.93064995910468, 109.99893835286984, 110.01742202148171, 110.03941481464986, 110.17904365079806, 110.18281639843386, 110.23325947751565, 110.3177714711539, 110.48562480041149, 111.17105511646048, 111.59302758109214, 111.67937391305752, 111.68054927766195, 111.86494914489775, 111.87831035558057, 111.92702649431767, 111.94725981805385, 111.95651829147782, 112.76129317687322, 112.97707023548239, 113.31012143295351, 113.31907301030253, 113.33608898934749, 113.45151629050484, 113.48662737235054, 113.51837495924265, 113.74716418269216, 114.99390289344149, 115.130791228107, 115.14329649992568, 115.29650567604294, 115.98575867487421, 116.5329401826976, 116.60657452310119, 116.69146514870941, 116.8601632113606, 116.90226545156396, 116.90456134054315, 117.09023014464375, 117.84022546099274, 117.93358785067777, 118.22188617277065, 118.31112409940485, 118.31126496127368, 118.35959571976099, 118.44502589563729, 118.68737713364942, 118.70533831253692, 118.73716416114559, 119.53488466813108, 119.95666486608974, 119.96988493144072, 119.99520352092328, 120.05812774749531, 120.07422185780136, 120.11889982231756, 120.44947780062483, 121.08257718654161, 121.67267433830297, 121.77033746362304, 121.80077849938574, 121.81945909011415, 121.92436805261667, 121.92725959331199, 122.02595516244244, 122.24650066054731, 122.80956482661308, 123.28135655787128, 123.29470355603456, 123.30428594838837, 123.44543294379122, 123.4786147512599, 123.66320613656647, 124.50634684532173, 124.66624657192669, 124.99065273528655, 125.04354762327972, 125.06718435556704, 125.10848928677042, 125.30236609832241, 125.34818740219912, 125.36461293027145, 126.73908137806136, 126.78270672679361, 126.82462402715473, 126.83344547550585, 126.92015401931951, 126.98225620086164, 127.09578156345422, 128.39482062227913, 128.41704963554071, 128.42946786795395, 128.60847802733201, 128.65086318329998, 128.65240892077293, 128.77413218044734, 129.67754825945542, 129.69282047429559, 129.97078380576812, 130.06207808214239, 130.06680172199253, 130.25639695828886, 130.29920584670478, 130.36385504641726, 130.36796004447802, 131.84580567923732, 131.98963126528173, 131.99742134010719, 132.19554845525428, 132.2022518189674, 132.42298178310489, 132.47330511495664, 132.62218240865741, 132.68691843046597, 134.1849396686851, 134.40179565594966, 135.90173470727632, 136.40658126144788, 136.46197643585259, 136.4850278243288, 136.5837711246792, 136.60450392782644, 138.45361256244121, 138.50440833102184, 138.58049898780754, 139.95826998317733, 140.18157396889083, 140.36253590333516, 140.37881320902736, 140.52865573575977, 140.5622993725427, 140.70889416115179, 140.93794348748364, 141.96303614792265, 142.16582443858883, 142.16853676946116, 142.44591229268568, 142.92904073283128, 144.27731467337719, 144.35529034149798, 144.4379129490176, 144.80741474957014, 144.9193290646497, 145.00612588559599, 145.03006402265271, 145.32569651186978, 146.1519241892135, 146.29515317917551, 146.40407920874458, 146.43525782616209, 146.58905664596759, 146.88814173333515, 147.44011616791369, 147.4825223530639, 147.66242358176973, 147.68284789470178, 147.98867918611791, 148.005069427275, 148.0290794300644, 148.39120687519102, 149.24657580473922, 149.68411283858853, 149.69205826216444, 149.71688459524785, 149.8458609257749, 149.92537899579938, 149.93772859509158, 149.9886843647968, 150.82435039748927, 150.89806545539571, 151.19916541636243, 151.30532842954702, 151.43541298356325, 151.45541589755527, 151.5446948193925, 151.55926572395637, 151.63483320080749, 152.39724949005387, 152.91920548449227, 152.94634750420471, 153.11188192118027, 153.12232591418234, 154.58969102217571, 154.60685477406017, 154.63070619928135, 154.71296176719773, 154.82490284546714, 154.88236946685814, 154.89225013054403, 154.91639329403557, 155.17339486296018, 155.77982378092406, 156.18672562235423, 156.23127623365602, 156.23789504694324, 156.30626654058651, 156.38807013743843, 156.43026651266055, 157.43442031603743, 157.81312811835031, 157.82543508867329, 157.94264185486443, 157.96415944249119, 158.00837127512744, 158.04794489542863, 158.91775087016507, 159.46761683724432, 159.5336098051402, 159.61277702432253, 159.66626172698255, 159.68900964191496, 159.69340221699667, 160.46831790424577, 160.5759924204219, 160.86129066630761, 161.06948824317377, 161.08561102466859, 161.19384347093211, 161.19604718063036, 161.32721927593838, 162.54910340009431, 162.66867311576539, 162.74086801283886, 162.78760823894959, 162.8376010286448, 162.84237564841192, 162.98679936313573, 163.22089239345854, 164.41000368012331, 164.61591321069045, 164.65839683644253, 164.74500704711417, 164.77563490659111, 165.19276992327767, 165.84832269379302, 166.17017818963495, 166.75252404827287, 166.97939538290782, 168.52744274665133, 168.84299337223806, 168.89855627091461, 169.32676944508876, 169.53821030403378, 170.27086339653945, 170.35862280573534, 170.41307763080917, 170.85610899506131, 171.16112145632607, 171.36694059106128, 172.69522989776158, 173.22619161623285, 173.30976129535406, 173.42102567048349, 173.55865318066435, 173.62019652144892, 173.87086149376128, 174.17619021360329, 174.43169471771662, 174.5013440224408, 175.37070185670089, 175.69720729059165, 175.84361891148822, 175.89210746049278, 177.30574358800837, 177.88614954739862, 178.00032514089091, 178.15361804201171, 178.25593183083379, 178.27089143854778, 178.337808689958, 178.34808140847082, 178.89603671913611, 179.87264542528203, 179.93155774757824, 180.37910587248865, 180.86017374455614, 181.66389009847606, 181.70346348365291, 182.01708187148157, 182.41233152116402, 182.49752428078278, 182.87732940826766, 183.4951582720104, 183.61861719359004, 183.77969783912093, 184.12532345297973, 185.19782584820766, 186.2290705113756, 186.41609881701447, 186.64972611457986, 186.74345710259053, 186.79353285434269, 188.10687622219319, 188.71536809195169, 188.73229685474988, 189.25512264539381, 190.75449267017476, 190.88391039870521, 190.97157605853076, 191.05985502940726, 191.08881088677231, 191.138211588084, 191.25287569067953, 192.03196239012857, 192.49914554520174, 192.50313045422982, 192.55456739778788, 192.56969847903201, 192.57658405944397, 192.75250511584323, 192.83256788927767, 192.83906737814516, 192.90851932994789, 193.93315104753086, 193.99576501360994, 194.11612797744934, 194.21700973812227, 194.22179649676391, 194.26387620137848, 194.34585064404922, 194.37093150158873, 194.53450327690757, 195.72598430160363, 195.77458463469685, 195.79106582954117, 195.92037941552795, 195.95647788958141, 196.09017964928347, 196.09906266871729, 196.17616119634869, 196.17996631704159, 197.22174610212187, 197.35503529309378, 197.39625955497308, 197.41629354439911, 197.51136137804085, 197.54018982354054, 197.71975808490998, 197.73235408879563, 197.84060529130983, 198.94757186264357, 198.95645368755254, 198.9842056179877, 199.04166839179766, 199.062297158604, 199.07249677088879, 199.10909367610518, 199.29604536077761, 199.31046414864329, 199.39985339437695, 200.4374834775565, 200.53959582011439, 200.64006615111307, 200.68120987732226, 200.79231527894996, 200.95030540702317, 200.95393370093907, 200.9956503860322, 201.02322757110278, 202.17063887842102, 202.2883067292625, 202.36713641293008, 202.41647839924511, 202.49109743195098, 202.55843092647913, 202.61056988399159, 203.7124146881919, 203.89866682339348, 203.97848483417832, 204.08906274411825, 204.08996198508197, 204.14568285241396, 204.18873660847436, 205.51142591829495, 205.57310338628702, 205.7308766929622, 205.75880378698116, 205.76196165858661, 205.87096076265118, 205.88399508278707, 206.06679395771141, 207.20665032021452, 207.21345655571912, 207.35766987387126, 207.38638357189424, 207.56400455716178, 207.57679806106171, 208.82296621449507, 208.88743295044452, 208.95420299701215, 208.97941877060472, 209.09498303298042, 209.30368138764962, 209.35374058194355, 210.46018505582231, 210.50270187154462, 210.56519718244095, 210.59656689564366, 210.73003461131509, 210.7888297392297, 210.91643795479521, 212.1218055030358, 212.28012912836201, 212.28637065260313, 212.31669804210341, 213.09641243845431, 213.10130521405006, 213.72560978187369, 213.7469610446928, 213.83957466265485, 214.0184946549297, 215.38667150275361, 215.44266433521292, 215.46773274309717, 215.50862227615195, 215.61581668851443, 215.6842188498768, 215.89300070792152, 216.97375760957104, 217.08950057603934, 217.2273871411615, 217.30633461664874, 218.6393844630874, 218.65382811320546, 218.7191935621621, 218.91434900559409, 218.9235301187534, 219.07391594225774, 220.36744405716092, 220.37889215487246, 220.39038151266331, 220.44798169938079, 220.55778405854858, 220.57271241876199, 220.57477836902581, 221.48963342415433, 221.90345409023163, 222.04617858443135, 222.08684311646792, 222.12225724191444, 222.265884404112, 223.61118493760159, 223.61562674008354, 223.61719250260518, 223.77009527487419, 223.82968116301919, 225.28585969540615, 225.30239147557342, 225.36133304421219, 225.42531234941146, 225.52521861999134, 226.88945436649678, 226.91140596993364, 226.9537198427316, 227.03994484004645, 227.12971090114203, 228.34902143138552, 228.3836896604476, 228.47523183450085, 228.55244023305107, 228.60231177060609, 228.74368841515965, 228.7991600464691, 230.12307241289687, 230.34952993350075, 230.38292417420419, 230.43940641777323, 231.82459212017403, 231.9415308020028, 231.97605525481725, 231.99484675776733, 232.05104090713021, 233.58345476578359, 233.58842065624998, 233.62515151070457, 233.69837308862657, 233.78970723170235, 233.80663485178201]

# %%
testarr
# Out:
# [0.9999999999873976,
#  13.122633923486505,
#  13.737126214282819,
#  16.231660000999728,
#  20.441512193654418,
#  24.585797519192134,
#  35.615222078673774,
#  35.63429986311264,
#  35.65159683375837,
#  35.65194885938133,
#  35.656808247806815,
#  35.66128336578122,
#  35.66412676978909,
#  35.66513583592684,
#  35.74913191051323,
#  35.80708034640827,
#  35.814507676207334,
#  35.81576026254471,
#  35.821141212236654,
#  35.83694513723587,
#  35.837160669756344,
#  35.84281096620718,
#  35.97515335748469,
#  36.04749284396758,
#  36.04951753565381,
#  36.05770415855835,
#  36.06864518156252,
#  36.07434372305107,
#  36.081995445148465,
#  36.09608818011025,
#  36.35360338333054,
#  36.363717773046496,
#  36.37900564955659,
#  36.38959099406705,
#  36.415269996343554,
#  36.45343144185457,
#  36.470534890021256,
#  36.47957930188273,
#  36.69925377265968,
#  36.721612604353275,
#  36.792948184140826,
#  36.80243725623794,
#  36.859572335554326,
#  36.875771716618544,
# ...

# %%
groups, current_group, first = [], [], testarr[0]
for item in testarr:
    # Check if this element falls under the current group
    if item - first <= 0.5:
        current_group.append(item)
    else:
        # If it doesn't, create a new group and add old to the result
        groups.append(current_group[:])
        current_group, first = [item], item
# Add the last group which was being gathered to the result
groups.append(current_group[:])

zmedian=[np.median(item) for item in groups]

print((testarr))
print(len(testarr))
print(zmedian)
print(len(zmedian))
# Out:
# [0.9999999999873976, 13.122633923486505, 13.737126214282819, 16.231660000999728, 20.441512193654418, 24.585797519192134, 35.615222078673774, 35.63429986311264, 35.65159683375837, 35.65194885938133, 35.656808247806815, 35.66128336578122, 35.66412676978909, 35.66513583592684, 35.74913191051323, 35.80708034640827, 35.814507676207334, 35.81576026254471, 35.821141212236654, 35.83694513723587, 35.837160669756344, 35.84281096620718, 35.97515335748469, 36.04749284396758, 36.04951753565381, 36.05770415855835, 36.06864518156252, 36.07434372305107, 36.081995445148465, 36.09608818011025, 36.35360338333054, 36.363717773046496, 36.37900564955659, 36.38959099406705, 36.415269996343554, 36.45343144185457, 36.470534890021256, 36.47957930188273, 36.69925377265968, 36.721612604353275, 36.792948184140826, 36.80243725623794, 36.859572335554326, 36.875771716618544, 37.123337156286695, 37.22198638230147, 37.22983652121831, 37.325799159366916, 37.3446911546576, 37.34649227736745, 37.59613206780812, 37.63505
# ...

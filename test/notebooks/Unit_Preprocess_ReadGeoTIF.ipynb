# %%
import sys
#Move to parent folder
sys.path.insert(0, '../croprows-cli/src/')

# %%
img_path = "../orthomosaics/results/testfile3/mosaic_5_5_1077px_25_tiles/"
img_name = "mosaic-cl_3-rw_2.jpg"

# %%
from scipy import misc
raster = misc.imread(img_path+img_name)
type(raster)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
imarray = plt.imread(img_path+img_name)
type(imarray)
# Out:
# numpy.ndarray

# %%
import cv2
im = cv2.imread(img_path+img_name)
type(im)
# Out:
# numpy.ndarray

# %%
from PIL import Image
import numpy as np
raster =Image.open(img_path+img_name)
print(raster.format, raster.size, raster.mode, raster.info)  
imarray=np.array(raster)
type(imarray)
# Out:
# JPEG (1078, 1077) RGB {'jfif_version': (1, 1), 'jfif': 257, 'jfif_density': (1, 1), 'jfif_unit': 0}
# numpy.ndarray

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
img = cv2.imread(img_path+img_name)
plt.figure(figsize=(7, 7))
plt.imshow(img)
plt.show()

# %%
import os, os.path
imgs = []
path = img_path
valid_images = [".tif",".jpg"]
for f in os.listdir(path):
    ext = os.path.splitext(f)[1]
    if ext.lower() not in valid_images:
        continue
    imgs.append((os.path.join(path,f)))

# %%
print(imgs)
# Out:
# ['../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_9-rw_4.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_12-rw_5.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_13-rw_8.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_14-rw_8.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_3-rw_11.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_10-rw_2.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_12-rw_2.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_11-rw_10.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_5-rw_2.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_12-rw_9.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_9-rw_11.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_tiles/mosaic-cl_10-rw_4.jpg', '../orthomosaics/cropped/mosaic_16_12_1077px_192_t
# ...
